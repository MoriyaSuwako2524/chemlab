# %%
import numpy as np

# %%
result = np.load("result_summary.npz", allow_pickle=True)
print(result.keys())
# Out:
# KeysView(NpzFile 'result_summary.npz' with keys: total_steps, history, total_converged, scan_type, scan_range...)

# %%
history = result["history"]
for h in history:
    print(h)
# Out:
# {'step_idx': 1, 'structure': array([['H', 'H', 'C', 'C', 'N', 'N'],
#        ['-1.3031367589', '-1.3004308851', '0.3017139599',
#         '-0.6187000460', '0.0198190605', '0.0313150632'],
#        ['0.4099851366', '0.4082246794', '-0.7610114777', '0.4885569363',
#         '1.6599617328', '-1.9442171839'],
#        ['0.8873757669', '-0.8885033881', '0.0041678804', '0.0005047517',
#         '0.0004279121', '-0.0039729230']], dtype='<U13'), 'energy': -186.7660400845, 'timestamp': '2025-12-14T15:19:40.090456', 'distance': 1.3, 'converged': True, 'row_idx': 1}
# {'step_idx': 2, 'structure': array([['H', 'H', 'C', 'C', 'N', 'N'],
#        ['-1.3049073342', '-1.3023884991', '0.2953703756',
#         '-0.6267314837', '0.0333254080', '0.0359119269'],
#        ['0.4130168205', '0.4115451057', '-0.7645122482', '0.4764768243',
#         '1.6750461137', '-1.9500727926'],
#        ['0.8888181640', '-0.8899550208', '0.0036579378', '0.0004341703',
# ...

# %%
result1 = np.load("result_step0039.npz")

# %%
result1
# Out:
# NpzFile 'result_step0039.npz' with keys: step_idx, structure, energy, timestamp, distance...
