# %%
# Out:
# Δd   analytic vs numeric: True
# ΔU_c analytic vs numeric: True
# ΔV   analytic vs numeric: True
# δU_null (into core) — field level: True
# δU_null (into core) — coefficient level: True

# %%
# Out:
# (array([[-0.27071232,  0.10484805,  0.25052782],
#         [-0.92519997,  0.56714366, -1.04018022],
#         [-0.15367595,  0.78985181, -1.22621585],
#         [-0.94800699, -0.56965394, -0.97715021],
#         [-0.77063171, -0.03371129, -1.03285925]]),
#  array([[ 1.14242738e-06, -6.09778008e-07,  1.46941639e-06],
#         [ 1.49267884e-06,  7.07125228e-07, -1.85849026e-06],
#         [-1.37062377e-06, -3.30106388e-07, -1.51528995e-06],
#         [ 1.20006019e-06, -1.82261914e-06,  2.69384541e-07],
#         [-4.46424376e-07,  1.11431360e-06, -1.38080260e-06]]))
