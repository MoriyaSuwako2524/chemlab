# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mecp_dist = np.load("dist.npy")
mecp_e1 = np.load("E1.npy")
mecp_e2 = np.load("E2.npy")

# %%
plt.plot(mecp_dist, mecp_e1)
plt.plot(mecp_dist, mecp_e2)

# %%
S_summary = np.load("S_summary.npz")
data = np.load("S_summary.npz")
print(list(data.keys()))
# Out:
# ['total_steps', 'history', 'total_converged', 'scan_type', 'scan_range', 'prefix']

# %%
S_dist = []
S_ene = []
for i in range(40):
    name = f"S_step{i:04d}.npz"
    a = np.load(name)
    S_dist.append(a["distance"])
    S_ene.append(a["energy"])
S_dist = np.array(S_dist)
S_ene = np.array(S_ene)


T_dist = []
T_ene = []
for i in range(40):
    name = f"T_step{i:04d}.npz"
    a = np.load(name)
    T_dist.append(a["distance"])
    T_ene.append(a["energy"])
T_dist = np.array(T_dist)
T_ene = np.array(T_ene)

# %%
mecp_dist = np.load("dist.npy")
for i in range(len(mecp_dist)):
    print(f"{i}:{mecp_dist[i]}")
mecp_e1 = np.load("E1.npy")
mecp_e2 = np.load("E2.npy")
mecp_dist = mecp_dist
mecp_e1 = mecp_e1
mecp_e2 = mecp_e2
plt.plot(S_dist, S_ene)
plt.plot(T_dist, T_ene)
plt.plot(mecp_dist, mecp_e1)
plt.plot(mecp_dist, mecp_e2)
plt.scatter(2.19,-207.2798)
# Out:
# 0:3.0
# 1:2.95
# 2:2.9
# 3:2.85
# 4:2.8
# 5:2.75
# 6:2.7
# 7:2.65
# 8:2.6
# 9:2.55
# 10:2.5
# 11:2.45
# 12:2.4
# 13:2.35
# 14:2.3
# 15:2.25
# 16:2.24
# 17:2.23
# 18:2.22
# 19:2.21
# 20:2.2
# 21:2.19
# 22:2.18
# 23:2.17
# 24:2.16
# 25:2.15
# 26:2.14
# 27:2.13
# 28:2.12
# 29:2.11
# 30:2.1
# 31:2.09
# 32:2.08
# 33:2.07
# 34:2.06
# 35:2.05
# 36:2.0
# 37:1.95
# 38:1.9
# 39:1.85
# 40:1.8
# 41:1.75
# 42:1.7
# 43:1.65
# 44:1.6
# 45:1.55
# 46:1.5

# %%
gap = np.load("gap.npy")
plt.plot(mecp_dist,gap)
